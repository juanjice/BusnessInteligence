# %%
import numpy as np
import pandas as pd
import random

# %% [markdown]
# Sheet 6
# Juan Manuel Jimenez
# Camilo Andres Fanco Beltran
# Ian Chona Canchona

# %% [markdown]
# Exercise 2.1
# Write a function kMeans(D, k, eps, mu = None) that runs the kMeans algorithm on
# a given 2D-numpy array D with k clusters and termination criterion eps. If no initial
# centroids mu are given, use random points in the range of the dataset.

# %%
def kMeans(D,k,eps,mu=None):    
    #Initialize centroids
    minValues = np.min(D, axis=0)
    maxValues = np.max(D, axis=0)
    if( (mu is None) or (mu.shape[0]!=k)):        
        mu=np.column_stack((np.random.uniform(D[0].min(),D[0].max(),[k,1]),np.random.uniform(D[1].min(),D[1].max(),[k,1])))
    #The cycle starts
    t=0
    print(centroids)
    print()
    while (t!=3):
        print(centroids)
        Cj=[[] for i in range(k)]
        print(Cj)
        t+=1
        for i in D:            
            fac=list(map(lambda x : np.linalg.norm(x-i), centroids))
            index_min=np.argmin(fac)            
            Cj[index_min].append(i.tolist())
            
            
        Cj=np.array(Cj)        
        for i in range(k):
            normCj=len(Cj[i])
            print(normCj)
            if not(normCj==0):
                centroids[i]=np.average(Cj[i],axis=0)
           
     
    return Dj,mu

irisSet=pd.read_csv('iris.csv').values[:,0:2]
irisSet= irisSet-np.mean(irisSet) / np.std(irisSet)
mu=np.array([[-0.98,-1.24],[-2.96,-1.16],[-1.69,-0.80]])
kMeans(irisSet,3,"eps",mu)

irisSet
# Out:
# [[-0.98 -1.24]
#  [-2.96 -1.16]
#  [-1.69 -0.8 ]]
#
# [[-0.98 -1.24]
#  [-2.96 -1.16]
#  [-1.69 -0.8 ]]
# [[], [], []]
# 150
# 0
# 0
# [[ 2.95910417  0.16977083]
#  [-2.96       -1.16      ]
#  [-1.69       -0.8       ]]
# [[ 2.95910417  0.16977083]
#  [-2.96       -1.16      ]
#  [-1.69       -0.8       ]]
# [[], [], []]
# 150
# 0
# 0
# [[ 2.95910417  0.16977083]
#  [-2.96       -1.16      ]
#  [-1.69       -0.8       ]]
# [[ 2.95910417  0.16977083]
#  [-2.96       -1.16      ]
#  [-1.69       -0.8       ]]
# [[], [], []]
# 150
# 0
# 0
# [[ 2.95910417  0.16977083]
#  [-2.96       -1.16      ]
#  [-1.69       -0.8       ]]
# array([[2.215770832093503, 0.6157708320935034],
#        [2.0157708320935037, 0.11577083209350336],
#        [1.8157708320935035, 0.31577083209350354],
#        [1.715770832093503, 0.21577083209350345],
#        [2.1157708320935034, 0.7157708320935035],
#        [2.5157708320935037, 1.0157708320935033],
#        [1.715770832093503, 0.5157708320935033],
#        [2.1157708320935034, 0.5157708320935033],
#        [1.5157708320935037, 0.015770832093503273],
#        [2.0157708320935037, 0.21577083209350345],
#        [2.5157708320935037, 0.8157708320935035],
#        [1.9157708320935032, 0.5157708320935033],
#        [1.9157708320935032, 0.11577083209350336],
#        [1.4157708320935032, 0.11577083209350336],
#        [2.915770832093503, 1.1157708320935034],
#        [2.8157708320935035, 1.5157708320935037],
#        [2.5157708320935037, 1.0157708320935033],
